# %% [markdown]
# # Python set

# %%
# language set
language = {'English', 'French', 'German'}

# removing 'German' from language
language.remove('German')

# Updated language set
print('Updated language set:', language)
# Out:
# Updated language set: {'French', 'English'}

# %% [markdown]
# # Deleting Element That Doesn't Exist give error

# %%
# # animal set
# animal = {'cat', 'dog', 'rabbit', 'guinea pig'}

# # Deleting 'fish' element
# animal.remove('fish')

# # Updated animal
# print('Updated animal set:', animal)

# %% [markdown]
# You can use the set discard() method if you do not want this error.
#
# The discard() method removes the specified element from the set. However, if the element doesn't exist, the set remains unchanged; you will not get an error.

# %% [markdown]
# # Add an element to a set

# %%
# set of vowels
vowels = {'a', 'e', 'i', 'u'}

# adding 'o'
vowels.add('o')
print('Vowels are:', vowels)

# adding 'a' again
vowels.add('a')
print('Vowels are:', vowels)
# Out:
# Vowels are: {'e', 'i', 'a', 'o', 'u'}
# Vowels are: {'e', 'i', 'a', 'o', 'u'}

# %% [markdown]
# # Add tuple to a set

# %%
# set of vowels
vowels = {'a', 'e', 'u'}

# a tuple ('i', 'o')
tup = ('i', 'o')

# adding tuple
vowels.add(tup)
print('Vowels are:', vowels)

# adding same tuple again
vowels.add(tup)
print('Vowels are:', vowels)
# Out:
# Vowels are: {'a', ('i', 'o'), 'e', 'u'}
# Vowels are: {'a', ('i', 'o'), 'e', 'u'}

# %% [markdown]
# # Python Set copy()

# %%
numbers = {1, 2, 3, 4}
new_numbers = numbers

new_numbers.add(5)

print('numbers: ', numbers)
print('new_numbers: ', new_numbers)
# Out:
# numbers:  {1, 2, 3, 4, 5}
# new_numbers:  {1, 2, 3, 4, 5}

# %% [markdown]
# # However, if you need the original set to be unchanged when the new set is modified, you can use the copy() method.

# %%
numbers = {1, 2, 3, 4}
new_numbers = numbers.copy()

new_numbers.add(5)

print('numbers: ', numbers)
print('new_numbers: ', new_numbers)
# Out:
# numbers:  {1, 2, 3, 4}
# new_numbers:  {1, 2, 3, 4, 5}

# %% [markdown]
# # Python Set clear()
# The clear() method removes all elements from the set.

# %%
# set of vowels
vowels = {'a', 'e', 'i', 'o', 'u'}
print('Vowels (before clear):', vowels)

# clearing vowels
vowels.clear()
print('Vowels (after clear):', vowels)
# Out:
# Vowels (before clear): {'e', 'i', 'a', 'o', 'u'}
# Vowels (after clear): set()

# %% [markdown]
# ![a-b.png](data:image/png;base64,...)

# %%
A = {'a', 'b', 'c', 'd'}
B = {'c', 'f', 'g'}

# Equivalent to A-B
print(A.difference(B))

# Equivalent to B-A
print(B.difference(A))
# Out:
# {'a', 'd', 'b'}
# {'g', 'f'}

# %% [markdown]
# # Set Difference Using - Operator.

# %%
A = {'a', 'b', 'c', 'd'}
B = {'c', 'f', 'g'}

print(A-B)

print(B-A)
# Out:
# {'a', 'd', 'b'}
# {'g', 'f'}

# %% [markdown]
# # difference_update()

# %%
A = {'a', 'c', 'g', 'd'}
B = {'c', 'f', 'g'}

result = A.difference_update(B)

print('A = ', A)
print('B = ', B)
print('result = ', result)
# Out:
# A =  {'a', 'd'}
# B =  {'g', 'c', 'f'}
# result =  None

# %% [markdown]
# # Set discard()

# %%
numbers = {2, 3, 4, 5}

numbers.discard(3)
print('numbers = ', numbers)

numbers.discard(10)
print('numbers = ', numbers)
# Out:
# numbers =  {2, 4, 5}
# numbers =  {2, 4, 5}

# %%
numbers = {2, 3, 5, 4}

# Returns None
# Meaning, absence of a return value 
print(numbers.discard(3))

print('numbers =', numbers)
# Out:
# None
# numbers = {2, 4, 5}

# %% [markdown]
# # intersection()
# ![intersection.png](data:image/png;base64,...)

# %%
A = {2, 3, 5, 4}
B = {2, 5, 100}
C = {2, 3, 8, 9, 10}

print(B.intersection(A))
print(B.intersection(C))
print(A.intersection(C))
print(C.intersection(A, B))
# Out:
# {2, 5}
# {2}
# {2, 3}
# {2}

# %%
A = {100, 7, 8}
B = {200, 4, 5}
C = {300, 2, 3}
D = {100, 200, 300}

print(A.intersection(D))
print(B.intersection(D))
print(C.intersection(D))
print(A.intersection(B, C, D))
# Out:
# {100}
# {200}
# {300}
# set()

# %% [markdown]
# # Set Intersection Using & operator

# %%
A = {100, 7, 8}
B = {200, 4, 5}
C = {300, 2, 3, 7}
D = {100, 200, 300}

print(A & C)
print(A & D)


print(A & C & D)
print(A & B & C & D)
# Out:
# {7}
# {100}
# set()
# set()

# %% [markdown]
# # Set intersection_update()

# %%
A = {1, 2, 3, 4}
B = {2, 3, 4, 5}

result = A.intersection_update(B)

print('result =', result)
print('A =', A)
print('B =', B)
# Out:
# result = None
# A = {2, 3, 4}
# B = {2, 3, 4, 5}

# %%
A = {1, 2, 3, 4}
B = {2, 3, 4, 5, 6}
C = {4, 5, 6, 9, 10}

result = C.intersection_update(B, A)

print('result =', result)
print('C =', C)
print('B =', B)
print('A =', A)
# Out:
# result = None
# C = {4}
# B = {2, 3, 4, 5, 6}
# A = {1, 2, 3, 4}

# %% [markdown]
# # Set isdisjoint()
# ![disjoint.png](data:image/png;base64,...)

# %%
A = {1, 2, 3, 4}
B = {5, 6, 7}
C = {4, 5, 6}

print('Are A and B disjoint?', A.isdisjoint(B))
print('Are A and C disjoint?', A.isdisjoint(C))
# Out:
# Are A and B disjoint? True
# Are A and C disjoint? False

# %%
A = {'a', 'b', 'c', 'd'}
B = ['b', 'e', 'f']
C = '5de4'
D ={1 : 'a', 2 : 'b'}
E ={'a' : 1, 'b' : 2}

print('Are A and B disjoint?', A.isdisjoint(B))
print('Are A and C disjoint?', A.isdisjoint(C))
print('Are A and D disjoint?', A.isdisjoint(D))
print('Are A and E disjoint?', A.isdisjoint(E))
# Out:
# Are A and B disjoint? False
# Are A and C disjoint? False
# Are A and D disjoint? True
# Are A and E disjoint? False

# %% [markdown]
# # Python Set issubset()
# The issubset() method returns True if all elements of a set are present in another set (passed as an argument). If not, it returns False.

# %% [markdown]
# ![issubset.png](data:image/png;base64,...)

# %%
A = {1, 2, 3}
B = {1, 2, 3, 4, 5}
C = {1, 2, 4, 5}

# Returns True
print(A.issubset(B))

# Returns False
# B is not subset of A
print(B.issubset(A))

# Returns False
print(A.issubset(C))

# Returns True
print(C.issubset(B))
# Out:
# True
# False
# False
# True

# %% [markdown]
# # Set pop()

# %%
A ={'a', 'b', 'c', 'd'}

print('Return Value is', A.pop())
print('A = ', A)
# Out:
# Return Value is a
# A =  {'d', 'c', 'b'}

# %% [markdown]
# # Python Set symmetric_difference()

# %% [markdown]
# ![symmetric_difference.png](data:image/png;base64,...)

# %%
A = {'a', 'b', 'c', 'd'}
B = {'c', 'd', 'e' }
C = {}

print(A.symmetric_difference(B))
print(B.symmetric_difference(A))

print(A.symmetric_difference(C))
print(B.symmetric_difference(C))
# Out:
# {'a', 'e', 'b'}
# {'a', 'e', 'b'}
# {'a', 'd', 'c', 'b'}
# {'d', 'c', 'e'}

# %% [markdown]
# # Symmetric difference using ^ operator

# %%
A = {'a', 'b', 'c', 'd'}
B = {'c', 'd', 'e' }

print(A ^ B)
print(B ^ A)

print(A ^ A)
print(B ^ B)
# Out:
# {'a', 'e', 'b'}
# {'a', 'e', 'b'}
# set()
# set()

# %% [markdown]
# # Set symmetric_difference_update()

# %%
A = {'a', 'c', 'd'}
B = {'c', 'd', 'e' }

result = A.symmetric_difference_update(B)

print('A =', A)
print('B =', B)
print('result =', result)
# Out:
# A = {'a', 'e'}
# B = {'d', 'c', 'e'}
# result = None

# %% [markdown]
# # Python Set union()
# ![union.png](data:image/png;base64,...)

# %%
A = {'a', 'c', 'd'}
B = {'c', 'd', 2 }
C = {1, 2, 3}

print('A U B =', A.union(B))
print('B U C =', B.union(C))
print('A U B U C =', A.union(B, C))
print('A.union() =', A.union())
# Out:
# A U B = {'a', 2, 'c', 'd'}
# B U C = {1, 2, 3, 'c', 'd'}
# A U B U C = {'a', 2, 1, 'c', 3, 'd'}
# A.union() = {'a', 'd', 'c'}

# %% [markdown]
# # Set Union Using the | Operator

# %%
A = {'a', 'c', 'd'}
B = {'c', 'd', 2 }
C = {1, 2, 3}

print('A U B =', A| B)
print('B U C =', B | C)
print('A U B U C =', A | B | C)
# Out:
# A U B = {'a', 2, 'c', 'd'}
# B U C = {1, 2, 3, 'c', 'd'}
# A U B U C = {'a', 2, 1, 'c', 3, 'd'}

# %% [markdown]
# # Python Set update()

# %%
A = {'a', 'b'}
B = {1, 2, 3}

result = A.update(B)

print('A =', A)
print('result =', result)
# Out:
# A = {'a', 1, 2, 3, 'b'}
# result = None

# %% [markdown]
# # Add elements of string and dictionary to Set

# %%
string_alphabet = 'abc'
numbers_set = {1, 2}

# add elements of the string to the set
numbers_set.update(string_alphabet)

print('numbers_set =', numbers_set)

info_dictionary = {'key': 1, 'lock' : 2}
numbers_set = {'a', 'b'}

# add keys of dictionary to the set
numbers_set.update(info_dictionary)
print('numbers_set =', numbers_set)
# Out:
# numbers_set = {1, 2, 'b', 'a', 'c'}
# numbers_set = {'a', 'lock', 'b', 'key'}

# %% [markdown]
# Note: If dictionaries are passed to the update() method, the keys of the dictionaries are added to the set.

# %% [markdown]
# [help](https://www.programiz.com/python-programming/methods/set/intersection)
